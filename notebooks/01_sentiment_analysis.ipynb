# %% [markdown]
# # 01 — Sentiment Analysis
# FinBERT and LM baseline score exploration.

# %%
import sys
sys.path.insert(0, '..')
import pandas as pd
from pathlib import Path
from src.visualization.charts import SentimentCharts

sentiment_path = Path('../data/processed/sentiment/sentiment_features.parquet')
if sentiment_path.exists():
    df = pd.read_parquet(sentiment_path)
    print(df.shape)
    display(df.describe())
    fig = SentimentCharts.sentiment_distribution(df)
    fig.show()
else:
    print('Run pipeline first.')
